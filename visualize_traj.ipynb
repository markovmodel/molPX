# %% [markdown]
# # It's a start...

# %%
import projX
# %matplotlib notebook

# %%
trajfile = '2a-ca-allfr.xtc'
topfile = '2a-ca.pdb'

# %%
ax, iwd, sample, geom = projX.visualize_traj(trajfile, topfile, 'apo_CA_proj0-proj1.dat', 
                     #return_data=True
                                          )
iwd
# Out:
# 16-12-16 18:49:11 pyemma.coordinates.clustering.regspace.RegularSpaceClustering[0] WARNING  Maximum number of cluster centers reached. Consider increasing max_centers or choose a larger minimum distance, dmin.
# 16-12-16 18:49:11 pyemma.coordinates.clustering.regspace.RegularSpaceClustering[0] INFO     Presumely finished estimation. Message: Used data for centers: 70.00%
# /home/mi/gph82/programs/PyEmma/pyemma/coordinates/clustering/regspace.py:151: UserWarning: Maximum number of cluster centers reached. Consider increasing max_centers or choose a larger minimum distance, dmin.
#   warnings.warn(msg)
# /home/mi/gph82/SOURCE_gph82/python/projection_explorer/projX.py:170: RuntimeWarning: divide by zero encountered in log
#   _plt.contourf(-_np.log(h).T, extent=irange)
# <img src="data:image/png;base64,...">
